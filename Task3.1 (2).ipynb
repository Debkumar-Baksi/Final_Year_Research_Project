# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
network_1=nx.Graph()
network_2=nx.Graph()
network_3=nx.Graph()
network_4=nx.Graph()

# %% [markdown]
# # NETWORK 1

# %%
network_1.add_edge(0,1,weight=800)
network_1.add_edge(0,5,weight=1000)
network_1.add_edge(1,2,weight=1100)
network_1.add_edge(1,5,weight=950)
network_1.add_edge(2,3,weight=250)
network_1.add_edge(2,4,weight=800)
network_1.add_edge(2,6,weight=1000)
network_1.add_edge(3,4,weight=800)
network_1.add_edge(3,6,weight=850)
network_1.add_edge(4,7,weight=1200)
network_1.add_edge(5,6,weight=1000)
network_1.add_edge(5,8,weight=1200)
network_1.add_edge(5,10,weight=1900)
network_1.add_edge(6,7,weight=1150)
network_1.add_edge(6,8,weight=1000)
network_1.add_edge(7,9,weight=900)
network_1.add_edge(8,9,weight=1000)
network_1.add_edge(8,10,weight=1400)
network_1.add_edge(8,11,weight=1000)
network_1.add_edge(9,12,weight=950)
network_1.add_edge(9,13,weight=850)
network_1.add_edge(10,11,weight=900)
network_1.add_edge(10,14,weight=1300)
network_1.add_edge(10,18,weight=2600)
network_1.add_edge(11,12,weight=900)
network_1.add_edge(11,15,weight=1000)
network_1.add_edge(12,13,weight=650)
network_1.add_edge(12,16,weight=1100)
network_1.add_edge(13,17,weight=1200)
network_1.add_edge(14,15,weight=600)
network_1.add_edge(14,19,weight=1300)
network_1.add_edge(15,16,weight=1000)
network_1.add_edge(15,20,weight=1000)
network_1.add_edge(15,21,weight=800)
network_1.add_edge(16,17,weight=800)
network_1.add_edge(16,21,weight=850)
network_1.add_edge(16,22,weight=1000)
network_1.add_edge(17,23,weight=900)
network_1.add_edge(18,19,weight=1200)
network_1.add_edge(19,20,weight=700)
network_1.add_edge(20,21,weight=300)
network_1.add_edge(21,22,weight=600)
network_1.add_edge(22,23,weight=900)


pos = nx.spring_layout(network_1 , k=0.5 )

plt.figure(figsize=(13, 13))

nx.draw_networkx(network_1, pos, with_labels=True, node_color='lightblue', node_size=500, font_weight='bold')

edge_labels = nx.get_edge_attributes(network_1, 'weight')

nx.draw_networkx_edge_labels(network_1, pos, edge_labels=edge_labels, font_color='red')

plt.title("24 Node US Network")

plt.show()

# %% [markdown]
# #  NETWORK 2

# %%
network_2.add_edge(1,2,weight=1310)
network_2.add_edge(1,3,weight=760)
network_2.add_edge(1,4,weight=390)
network_2.add_edge(2,3,weight=550)
network_2.add_edge(2,5,weight=390)
network_2.add_edge(2,8,weight=450)
network_2.add_edge(3,4,weight=660)
network_2.add_edge(3,5,weight=210)
network_2.add_edge(3,6,weight=390)
network_2.add_edge(4,7,weight=340)
network_2.add_edge(4,8,weight=1090)
network_2.add_edge(4,10,weight=660)
network_2.add_edge(5,6,weight=220)
network_2.add_edge(5,8,weight=300)
network_2.add_edge(5,11,weight=930)
network_2.add_edge(6,7,weight=730)
network_2.add_edge(6,8,weight=400)
network_2.add_edge(6,9,weight=350)
network_2.add_edge(7,9,weight=565)
network_2.add_edge(7,10,weight=320)
network_2.add_edge(8,9,weight=600)
network_2.add_edge(8,11,weight=820)
network_2.add_edge(9,10,weight=730)
network_2.add_edge(9,11,weight=320)
network_2.add_edge(10,11,weight=820)


pos = nx.spring_layout(network_2 , k=0.5 )

plt.figure(figsize=(13, 11))

nx.draw_networkx(network_2, pos, with_labels=True, node_color='lightblue', node_size=500, font_weight='bold')

edge_labels = nx.get_edge_attributes(network_2, 'weight')

nx.draw_networkx_edge_labels(network_2, pos, edge_labels=edge_labels, font_color='red')

plt.title("11 node COST 239 European Optical Network")

plt.show()

# %% [markdown]
# # NETWORK 3

# %%
network_3.add_edge(1,2,weight=1100)
network_3.add_edge(1,3,weight=1600)
network_3.add_edge(1,8,weight=2800)
network_3.add_edge(2,3,weight=600)
network_3.add_edge(2,4,weight=1000)
network_3.add_edge(3,6,weight=2000)
network_3.add_edge(4,5,weight=600)
network_3.add_edge(4,11,weight=2400)
network_3.add_edge(5,6,weight=1100)
network_3.add_edge(5,7,weight=800)
network_3.add_edge(6,10,weight=1200)
network_3.add_edge(6,13,weight=2000)
network_3.add_edge(7,8,weight=700)
network_3.add_edge(8,9,weight=700)
network_3.add_edge(9,10,weight=900)
network_3.add_edge(9,12,weight=500)
network_3.add_edge(9,14,weight=500)
network_3.add_edge(11,12,weight=800)
network_3.add_edge(11,14,weight=800)
network_3.add_edge(13,14,weight=300)

pos = nx.spring_layout(network_3 , k=0.5 )

plt.figure(figsize=(13, 11))

nx.draw_networkx(network_3, pos, with_labels=True, node_color='lightblue', node_size=500, font_weight='bold')

edge_labels = nx.get_edge_attributes(network_3, 'weight')

nx.draw_networkx_edge_labels(network_3, pos, edge_labels=edge_labels, font_color='red')

plt.title("14-node National Science Foundation Network")

plt.show()

# %%
import pickle
with open("network_1.gpickle", "wb") as f:
    pickle.dump(network_1, f, pickle.HIGHEST_PROTOCOL)

with open("network_2.gpickle", "wb") as f:
    pickle.dump(network_2, f, pickle.HIGHEST_PROTOCOL)

with open("network_3.gpickle", "wb") as f:
    pickle.dump(network_3, f, pickle.HIGHEST_PROTOCOL)

# %%
with open("network_1.gpickle", "rb") as f:
    loaded_network_1 = pickle.load(f)

with open("network_2.gpickle", "rb") as f:
    loaded_network_2 = pickle.load(f)

with open("network_3.gpickle", "rb") as f:
    loaded_network_3 = pickle.load(f)

# %%
print(loaded_network_1)
print(loaded_network_2)
print(loaded_network_3)
# Out:
# Graph with 24 nodes and 43 edges
# Graph with 11 nodes and 25 edges
# Graph with 14 nodes and 20 edges
