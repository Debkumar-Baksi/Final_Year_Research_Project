# %%
import random
def generate_requests(node_request ,num_requests, demand):
    requests = []
    for _ in range(num_requests):
        source = random.randint(1, node_request)
        destination = random.randint(1, node_request)
        #for making sure source and destination is not same
        while destination == source:
            destination = random.randint(1, node_request)
            
            
        if demand_type == 'variable':
            demand = 20 * random.choice([2, 3, 4, 5, 6])
        else:
            demand = demand  # fixed demand
        
        new_req={
            "source":source,
            "destination":destination,
            "bandwidth":demand
        }
        
        requests.append(new_req)
        
    return requests
node_request = int(input("Enter the maximum number of nodes : "))
num_requests = int(input("Enter the number of requests: "))
demand_type = input("Enter demand type (40 or 80 for fixed, or variable): ").lower()

if demand_type == '40':
    demand = 40
elif demand_type == '80':
    demand = 80
elif demand_type == 'variable':
    demand = "variable"
else:
    print("Invalid demand type.")
    exit()

result = generate_requests(node_request ,num_requests, demand)
for req in result:
    print(req)

# print(result)
# Out:
# Enter the maximum number of nodes : 24
# Enter the number of requests: 500
# Enter demand type (40 or 80 for fixed, or variable): variable
# {'source': 18, 'destination': 1, 'bandwidth': 60}
# {'source': 9, 'destination': 3, 'bandwidth': 100}
# {'source': 24, 'destination': 23, 'bandwidth': 120}
# {'source': 16, 'destination': 19, 'bandwidth': 80}
# {'source': 5, 'destination': 6, 'bandwidth': 100}
# {'source': 22, 'destination': 24, 'bandwidth': 40}
# {'source': 8, 'destination': 3, 'bandwidth': 40}
# {'source': 1, 'destination': 16, 'bandwidth': 80}
# {'source': 20, 'destination': 1, 'bandwidth': 40}
# {'source': 21, 'destination': 18, 'bandwidth': 80}
# {'source': 14, 'destination': 24, 'bandwidth': 120}
# {'source': 14, 'destination': 9, 'bandwidth': 60}
# {'source': 20, 'destination': 19, 'bandwidth': 100}
# {'source': 1, 'destination': 15, 'bandwidth': 80}
# {'source': 19, 'destination': 5, 'bandwidth': 100}
# {'source': 1, 'destination': 18, 'bandwidth': 60}
# {'source': 12, 'destination': 20, 'bandwidth': 80}
# {'source': 2, 'destination': 4, 'bandwidth': 120}
# {'source': 12, 'destination': 7, 'bandwidth': 100}
# {'source': 1, 'destination': 21, 'bandwidth': 60}
# {'source': 3, 'destination': 9, 'bandwidth': 120}
# {'source': 11, 'destination': 12, 'bandwidth': 120}
# {'source': 9, 'destination': 4, 'bandwidth': 80}
# {'source': 2, 'destination': 6, 'bandwidth': 120}
# {'source': 14, 'destination': 15, 'bandwidth': 100}
# {'source': 4, 'destination': 12, 'bandwidth': 60}
# {'source': 6, 'destination': 8, 'bandwidth': 100}
# {'source': 2, 'destination': 24, 'bandwidth': 80}
# {'source': 23, 'destination': 18, 'bandwidth': 120}
# {'source': 18, 'destination': 24, 'bandwidth': 80}
# {'source': 15, 'destination': 8, 'bandwidth': 100}
# {'source': 6, 'destination': 2, 'bandwidth': 60}
# {'source': 13, 'destination': 23, 'bandwidth': 80}
# {'source': 23, 'destination': 11, 'bandwidth': 60}
# {'source': 7, 'destination': 20, 'bandwidth': 60}
# {'source': 10, 'destination': 1, 'bandwidth': 100}
# {'source': 20, 'destination': 6, 'bandwidth': 120}
# {'source': 20, 'destination': 15, 'bandwidth': 80}
# {'source': 21, 'destination': 3, 'bandwidth': 80}
# {'source': 6, 'destination': 21, 'bandwidth': 60}
# {'source': 15, 'destination': 23, 'bandwidth': 80}
# {'source': 17, 'destination': 3, 'bandwidth': 60}
# {'source': 14, 'destination': 20, 'bandwidth': 100}
# {'source': 21, 'destination': 23, 'bandwidth': 40}
# {'source': 12, 'destination': 1, 'bandwidth': 100}
# {'source': 4, 'destination': 8, 'bandwidth': 80}
# {'source': 23, 'destination': 16, 'bandwidth': 100}
# {'source': 10, 'destination': 21, 'bandwidth': 60}
# {'source': 9, 'destination': 12, 'bandwidth': 100}
# {'source': 15, 'destination': 8, 'bandwidth': 120}
# {'source': 11, 'destination': 21, 'bandwidth': 120}
# {'source': 17, 'destination': 9, 'bandwidth': 60}
# {'source': 9, 'destination': 2, 'bandwidth': 120}
# {'source': 21, 'destination': 23, 'bandwidth': 80}
# {'source': 2, 'destination': 19, 'bandwidth': 100}
# {'source': 13, 'destination': 8, 'bandwidth': 80}
# {'source': 16, 'destination': 3, 'bandwidth': 120}
# {'source': 16, 'destination': 20, 'bandwidth': 80}
# {'source': 13, 'destination': 12, 'bandwidth': 100}
# {'source': 23, 'destination': 19, 'bandwidth': 100}
# {'source': 1, 'destination': 14, 'bandwidth': 40}
# {'source': 19, 'destination': 5, 'bandwidth': 40}
# {'source': 18, 'destination': 13, 'bandwidth': 60}
# {'source': 4, 'destination': 14, 'bandwidth': 80}
# {'source': 14, 'destination': 11, 'bandwidth': 120}
# {'source': 20, 'destination': 16, 'bandwidth': 120}
# {'source': 20, 'destination': 11, 'bandwidth': 40}
# {'source': 10, 'destination': 6, 'bandwidth': 80}
# {'source': 12, 'destination': 22, 'bandwidth': 100}
# {'source': 15, 'destination': 17, 'bandwidth': 120}
# {'source': 11, 'destination': 12, 'bandwidth': 40}
# {'source': 17, 'destination': 22, 'bandwidth': 100}
# {'source': 1, 'destination': 8, 'bandwidth': 80}
# {'source': 10, 'destination': 18, 'bandwidth': 40}
# {'source': 9, 'destination': 23, 'bandwidth': 60}
# {'source': 21, 'destination': 6, 'bandwidth': 120}
# {'source': 1, 'destination': 20, 'bandwidth': 80}
# {'source': 9, 'destination': 12, 'bandwidth': 100}
# {'source': 6, 'destination': 3, 'bandwidth': 100}
# {'source': 10, 'destination': 22, 'bandwidth': 100}
# {'source': 7, 'destination': 23, 'bandwidth': 60}
# {'source': 22, 'destination': 16, 'bandwidth': 100}
# {'source': 11, 'destination': 5, 'bandwidth': 120}
# {'source': 6, 'destination': 13, 'bandwidth': 120}
# {'source': 12, 'destination': 21, 'bandwidth': 120}
# {'source': 2, 'destination': 14, 'bandwidth': 80}
# {'source': 17, 'destination': 9, 'bandwidth': 120}
# {'source': 15, 'destination': 21, 'bandwidth': 120}
# {'source': 5, 'destination': 24, 'bandwidth': 120}
# {'source': 3, 'destination': 13, 'bandwidth': 120}
# {'source': 10, 'destination': 15, 'bandwidth': 60}
# {'source': 15, 'destination': 16, 'bandwidth': 60}
# {'source': 17, 'destination': 7, 'bandwidth': 120}
# {'source': 8, 'destination': 22, 'bandwidth': 40}
# {'source': 7, 'destination': 3, 'bandwidth': 40}
# {'source': 8, 'destination': 6, 'bandwidth': 40}
# {'source': 2, 'destination': 20, 'bandwidth': 80}
# {'source': 13, 'destination': 20, 'bandwidth': 60}
# {'source': 16, 'destination': 19, 'bandwidth': 40}
# {'source': 6, 'destination': 9, 'bandwidth': 80}
# {'source': 18, 'destination': 17, 'bandwidth': 60}
# {'source': 20, 'destination': 17, 'bandwidth': 100}
# {'source': 9, 'destination': 23, 'bandwidth': 80}
# {'source': 18, 'destination': 17, 'bandwidth': 100}
# {'source': 10, 'destination': 1, 'bandwidth': 100}
# {'source': 4, 'destination': 19, 'bandwidth': 40}
# {'source': 4, 'destination': 18, 'bandwidth': 60}
# {'source': 5, 'destination': 14, 'bandwidth': 60}
# {'source': 11, 'destination': 17, 'bandwidth': 120}
# {'source': 5, 'destination': 4, 'bandwidth': 100}
# {'source': 20, 'destination': 22, 'bandwidth': 100}
# {'source': 13, 'destination': 6, 'bandwidth': 120}
# {'source': 10, 'destination': 18, 'bandwidth': 40}
# {'source': 9, 'destination': 5, 'bandwidth': 120}
# {'source': 2, 'destination': 13, 'bandwidth': 60}
# {'source': 17, 'destination': 13, 'bandwidth': 100}
# {'source': 6, 'destination': 23, 'bandwidth': 100}
# {'source': 12, 'destination': 19, 'bandwidth': 80}
# {'source': 5, 'destination': 16, 'bandwidth': 100}
# {'source': 5, 'destination': 15, 'bandwidth': 80}
# {'source': 13, 'destination': 7, 'bandwidth': 120}
# {'source': 22, 'destination': 8, 'bandwidth': 100}
# {'source': 21, 'destination': 9, 'bandwidth': 100}
# {'source': 13, 'destination': 11, 'bandwidth': 40}
# {'source': 6, 'destination': 1, 'bandwidth': 120}
# {'source': 2, 'destination': 1, 'bandwidth': 60}
# {'source': 17, 'destination': 21, 'bandwidth': 80}
# {'source': 2, 'destination': 17, 'bandwidth': 80}
# {'source': 3, 'destination': 2, 'bandwidth': 120}
# {'source': 14, 'destination': 13, 'bandwidth': 100}
# {'source': 6, 'destination': 12, 'bandwidth': 100}
# {'source': 16, 'destination': 15, 'bandwidth': 80}
# {'source': 18, 'destination': 8, 'bandwidth': 80}
# {'source': 9, 'destination': 22, 'bandwidth': 60}
# {'source': 17, 'destination': 2, 'bandwidth': 100}
# {'source': 22, 'destination': 9, 'bandwidth': 60}
# {'source': 10, 'destination': 16, 'bandwidth': 120}
# {'source': 9, 'destination': 13, 'bandwidth': 80}
# {'source': 2, 'destination': 8, 'bandwidth': 80}
# {'source': 19, 'destination': 22, 'bandwidth': 120}
# {'source': 19, 'destination': 22, 'bandwidth': 120}
# {'source': 17, 'destination': 15, 'bandwidth': 120}
# {'source': 10, 'destination': 17, 'bandwidth': 40}
# {'source': 3, 'destination': 12, 'bandwidth': 60}
# {'source': 17, 'destination': 8, 'bandwidth': 100}
# {'source': 16, 'destination': 7, 'bandwidth': 60}
# {'source': 21, 'destination': 7, 'bandwidth': 60}
# {'source': 21, 'destination': 4, 'bandwidth': 100}
# {'source': 4, 'destination': 14, 'bandwidth': 60}
# {'source': 16, 'destination': 23, 'bandwidth': 120}
# {'source': 16, 'destination': 5, 'bandwidth': 40}
# {'source': 10, 'destination': 7, 'bandwidth': 120}
# {'source': 24, 'destination': 12, 'bandwidth': 100}
# {'source': 14, 'destination': 15, 'bandwidth': 40}
# {'source': 4, 'destination': 10, 'bandwidth': 40}
# {'source': 23, 'destination': 24, 'bandwidth': 80}
# {'source': 19, 'destination': 2, 'bandwidth': 80}
# {'source': 13, 'destination': 9, 'bandwidth': 120}
# {'source': 4, 'destination': 17, 'bandwidth': 80}
# {'source': 4, 'destination': 23, 'bandwidth': 40}
# {'source': 7, 'destination': 23, 'bandwidth': 60}
# {'source': 1, 'destination': 2, 'bandwidth': 80}
# {'source': 5, 'destination': 20, 'bandwidth': 80}
# {'source': 14, 'destination': 3, 'bandwidth': 60}
# {'source': 11, 'destination': 14, 'bandwidth': 40}
# {'source': 11, 'destination': 18, 'bandwidth': 40}
# {'source': 11, 'destination': 15, 'bandwidth': 100}
# {'source': 13, 'destination': 5, 'bandwidth': 60}
# {'source': 16, 'destination': 4, 'bandwidth': 60}
# {'source': 11, 'destination': 17, 'bandwidth': 40}
# {'source': 16, 'destination': 21, 'bandwidth': 60}
# {'source': 13, 'destination': 7, 'bandwidth': 100}
# {'source': 16, 'destination': 2, 'bandwidth': 100}
# {'source': 23, 'destination': 21, 'bandwidth': 80}
# {'source': 15, 'destination': 1, 'bandwidth': 80}
# {'source': 12, 'destination': 17, 'bandwidth': 40}
# {'source': 1, 'destination': 11, 'bandwidth': 40}
# {'source': 8, 'destination': 19, 'bandwidth': 120}
# {'source': 16, 'destination': 18, 'bandwidth': 60}
# {'source': 10, 'destination': 13, 'bandwidth': 120}
# {'source': 1, 'destination': 12, 'bandwidth': 40}
# {'source': 21, 'destination': 22, 'bandwidth': 80}
# {'source': 13, 'destination': 20, 'bandwidth': 120}
# {'source': 4, 'destination': 14, 'bandwidth': 100}
# {'source': 15, 'destination': 16, 'bandwidth': 60}
# {'source': 11, 'destination': 21, 'bandwidth': 40}
# {'source': 14, 'destination': 4, 'bandwidth': 40}
# {'source': 8, 'destination': 2, 'bandwidth': 60}
# {'source': 6, 'destination': 16, 'bandwidth': 120}
# {'source': 21, 'destination': 5, 'bandwidth': 40}
# {'source': 5, 'destination': 6, 'bandwidth': 120}
# {'source': 23, 'destination': 19, 'bandwidth': 120}
# {'source': 11, 'destination': 8, 'bandwidth': 120}
# {'source': 4, 'destination': 23, 'bandwidth': 120}
# {'source': 16, 'destination': 17, 'bandwidth': 120}
# {'source': 17, 'destination': 19, 'bandwidth': 120}
# {'source': 10, 'destination': 13, 'bandwidth': 100}
# {'source': 10, 'destination': 9, 'bandwidth': 40}
# {'source': 4, 'destination': 14, 'bandwidth': 60}
# {'source': 24, 'destination': 6, 'bandwidth': 120}
# {'source': 9, 'destination': 1, 'bandwidth': 80}
# {'source': 5, 'destination': 18, 'bandwidth': 80}
# {'source': 5, 'destination': 3, 'bandwidth': 100}
# {'source': 7, 'destination': 9, 'bandwidth': 100}
# {'source': 7, 'destination': 24, 'bandwidth': 80}
# {'source': 20, 'destination': 12, 'bandwidth': 100}
# {'source': 3, 'destination': 9, 'bandwidth': 80}
# {'source': 6, 'destination': 1, 'bandwidth': 100}
# {'source': 21, 'destination': 16, 'bandwidth': 60}
# {'source': 2, 'destination': 16, 'bandwidth': 40}
# {'source': 13, 'destination': 7, 'bandwidth': 120}
# {'source': 19, 'destination': 11, 'bandwidth': 60}
# {'source': 3, 'destination': 5, 'bandwidth': 120}
# {'source': 21, 'destination': 18, 'bandwidth': 120}
# {'source': 12, 'destination': 6, 'bandwidth': 60}
# {'source': 3, 'destination': 5, 'bandwidth': 80}
# {'source': 22, 'destination': 14, 'bandwidth': 100}
# {'source': 16, 'destination': 24, 'bandwidth': 60}
# {'source': 15, 'destination': 13, 'bandwidth': 60}
# {'source': 14, 'destination': 4, 'bandwidth': 60}
# {'source': 23, 'destination': 17, 'bandwidth': 40}
# {'source': 3, 'destination': 10, 'bandwidth': 100}
# {'source': 17, 'destination': 23, 'bandwidth': 80}
# {'source': 15, 'destination': 18, 'bandwidth': 100}
# {'source': 9, 'destination': 13, 'bandwidth': 40}
# {'source': 10, 'destination': 16, 'bandwidth': 120}
# {'source': 4, 'destination': 2, 'bandwidth': 40}
# {'source': 1, 'destination': 17, 'bandwidth': 80}
# {'source': 20, 'destination': 7, 'bandwidth': 120}
# {'source': 3, 'destination': 17, 'bandwidth': 120}
# {'source': 19, 'destination': 22, 'bandwidth': 80}
# {'source': 12, 'destination': 13, 'bandwidth': 80}
# {'source': 2, 'destination': 21, 'bandwidth': 80}
# {'source': 17, 'destination': 24, 'bandwidth': 100}
# {'source': 8, 'destination': 13, 'bandwidth': 100}
# {'source': 4, 'destination': 21, 'bandwidth': 100}
# {'source': 7, 'destination': 1, 'bandwidth': 100}
# {'source': 1, 'destination': 4, 'bandwidth': 80}
# {'source': 24, 'destination': 9, 'bandwidth': 60}
# {'source': 1, 'destination': 24, 'bandwidth': 100}
# {'source': 8, 'destination': 6, 'bandwidth': 100}
# {'source': 18, 'destination': 14, 'bandwidth': 120}
# {'source': 16, 'destination': 18, 'bandwidth': 80}
# {'source': 3, 'destination': 11, 'bandwidth': 80}
# {'source': 15, 'destination': 16, 'bandwidth': 40}
# {'source': 6, 'destination': 10, 'bandwidth': 60}
# {'source': 20, 'destination': 15, 'bandwidth': 80}
# {'source': 24, 'destination': 6, 'bandwidth': 80}
# {'source': 9, 'destination': 19, 'bandwidth': 80}
# {'source': 20, 'destination': 13, 'bandwidth': 120}
# {'source': 22, 'destination': 8, 'bandwidth': 60}
# {'source': 11, 'destination': 6, 'bandwidth': 100}
# {'source': 21, 'destination': 1, 'bandwidth': 80}
# {'source': 13, 'destination': 6, 'bandwidth': 80}
# {'source': 4, 'destination': 24, 'bandwidth': 80}
# {'source': 17, 'destination': 6, 'bandwidth': 80}
# {'source': 15, 'destination': 19, 'bandwidth': 100}
# {'source': 3, 'destination': 21, 'bandwidth': 80}
# {'source': 20, 'destination': 14, 'bandwidth': 100}
# {'source': 17, 'destination': 19, 'bandwidth': 80}
# {'source': 20, 'destination': 19, 'bandwidth': 60}
# {'source': 14, 'destination': 1, 'bandwidth': 80}
# {'source': 1, 'destination': 19, 'bandwidth': 100}
# {'source': 12, 'destination': 21, 'bandwidth': 100}
# {'source': 23, 'destination': 4, 'bandwidth': 100}
# {'source': 12, 'destination': 2, 'bandwidth': 80}
# {'source': 1, 'destination': 16, 'bandwidth': 40}
# {'source': 7, 'destination': 22, 'bandwidth': 80}
# {'source': 11, 'destination': 21, 'bandwidth': 100}
# {'source': 7, 'destination': 23, 'bandwidth': 80}
# {'source': 24, 'destination': 4, 'bandwidth': 80}
# {'source': 1, 'destination': 6, 'bandwidth': 120}
# {'source': 19, 'destination': 5, 'bandwidth': 80}
# {'source': 2, 'destination': 17, 'bandwidth': 80}
# {'source': 21, 'destination': 15, 'bandwidth': 100}
# {'source': 8, 'destination': 10, 'bandwidth': 60}
# {'source': 23, 'destination': 21, 'bandwidth': 60}
# {'source': 12, 'destination': 2, 'bandwidth': 40}
# {'source': 14, 'destination': 23, 'bandwidth': 120}
# {'source': 13, 'destination': 14, 'bandwidth': 60}
# {'source': 21, 'destination': 9, 'bandwidth': 80}
# {'source': 11, 'destination': 12, 'bandwidth': 120}
# {'source': 20, 'destination': 3, 'bandwidth': 40}
# {'source': 3, 'destination': 2, 'bandwidth': 80}
# {'source': 3, 'destination': 20, 'bandwidth': 80}
# {'source': 10, 'destination': 15, 'bandwidth': 80}
# {'source': 9, 'destination': 15, 'bandwidth': 40}
# {'source': 9, 'destination': 19, 'bandwidth': 100}
# {'source': 1, 'destination': 8, 'bandwidth': 40}
# {'source': 3, 'destination': 2, 'bandwidth': 100}
# {'source': 4, 'destination': 18, 'bandwidth': 100}
# {'source': 21, 'destination': 15, 'bandwidth': 100}
# {'source': 22, 'destination': 11, 'bandwidth': 120}
# {'source': 22, 'destination': 23, 'bandwidth': 120}
# {'source': 9, 'destination': 3, 'bandwidth': 60}
# {'source': 10, 'destination': 2, 'bandwidth': 120}
# {'source': 23, 'destination': 24, 'bandwidth': 40}
# {'source': 11, 'destination': 8, 'bandwidth': 100}
# {'source': 16, 'destination': 14, 'bandwidth': 60}
# {'source': 2, 'destination': 12, 'bandwidth': 120}
# {'source': 21, 'destination': 20, 'bandwidth': 100}
# {'source': 22, 'destination': 9, 'bandwidth': 80}
# {'source': 13, 'destination': 6, 'bandwidth': 120}
# {'source': 13, 'destination': 24, 'bandwidth': 100}
# {'source': 5, 'destination': 18, 'bandwidth': 120}
# {'source': 7, 'destination': 23, 'bandwidth': 40}
# {'source': 1, 'destination': 21, 'bandwidth': 100}
# {'source': 14, 'destination': 5, 'bandwidth': 60}
# {'source': 2, 'destination': 16, 'bandwidth': 60}
# {'source': 17, 'destination': 11, 'bandwidth': 60}
# {'source': 17, 'destination': 1, 'bandwidth': 120}
# {'source': 8, 'destination': 19, 'bandwidth': 80}
# {'source': 10, 'destination': 19, 'bandwidth': 120}
# {'source': 16, 'destination': 12, 'bandwidth': 40}
# {'source': 12, 'destination': 3, 'bandwidth': 100}
# {'source': 1, 'destination': 18, 'bandwidth': 100}
# {'source': 1, 'destination': 17, 'bandwidth': 100}
# {'source': 13, 'destination': 10, 'bandwidth': 120}
# {'source': 23, 'destination': 22, 'bandwidth': 80}
# {'source': 11, 'destination': 1, 'bandwidth': 120}
# {'source': 7, 'destination': 23, 'bandwidth': 100}
# {'source': 3, 'destination': 7, 'bandwidth': 120}
# {'source': 1, 'destination': 21, 'bandwidth': 120}
# {'source': 21, 'destination': 22, 'bandwidth': 100}
# {'source': 16, 'destination': 12, 'bandwidth': 60}
# {'source': 3, 'destination': 1, 'bandwidth': 100}
# {'source': 17, 'destination': 5, 'bandwidth': 100}
# {'source': 7, 'destination': 19, 'bandwidth': 100}
# {'source': 14, 'destination': 22, 'bandwidth': 120}
# {'source': 18, 'destination': 2, 'bandwidth': 120}
# {'source': 12, 'destination': 5, 'bandwidth': 100}
# {'source': 5, 'destination': 11, 'bandwidth': 100}
# {'source': 6, 'destination': 10, 'bandwidth': 120}
# {'source': 19, 'destination': 3, 'bandwidth': 60}
# {'source': 11, 'destination': 3, 'bandwidth': 40}
# {'source': 15, 'destination': 21, 'bandwidth': 120}
# {'source': 9, 'destination': 11, 'bandwidth': 120}
# {'source': 2, 'destination': 11, 'bandwidth': 40}
# {'source': 11, 'destination': 22, 'bandwidth': 120}
# {'source': 12, 'destination': 19, 'bandwidth': 60}
# {'source': 4, 'destination': 10, 'bandwidth': 60}
# {'source': 10, 'destination': 8, 'bandwidth': 120}
# {'source': 22, 'destination': 11, 'bandwidth': 60}
# {'source': 13, 'destination': 8, 'bandwidth': 60}
# {'source': 9, 'destination': 23, 'bandwidth': 120}
# {'source': 10, 'destination': 5, 'bandwidth': 40}
# {'source': 15, 'destination': 14, 'bandwidth': 40}
# {'source': 17, 'destination': 24, 'bandwidth': 100}
# {'source': 10, 'destination': 22, 'bandwidth': 40}
# {'source': 16, 'destination': 17, 'bandwidth': 100}
# {'source': 11, 'destination': 10, 'bandwidth': 120}
# {'source': 7, 'destination': 8, 'bandwidth': 40}
# {'source': 15, 'destination': 19, 'bandwidth': 60}
# {'source': 1, 'destination': 14, 'bandwidth': 60}
# {'source': 19, 'destination': 24, 'bandwidth': 80}
# {'source': 19, 'destination': 18, 'bandwidth': 100}
# {'source': 12, 'destination': 5, 'bandwidth': 100}
# {'source': 7, 'destination': 10, 'bandwidth': 60}
# {'source': 11, 'destination': 15, 'bandwidth': 120}
# {'source': 14, 'destination': 7, 'bandwidth': 60}
# {'source': 24, 'destination': 2, 'bandwidth': 80}
# {'source': 3, 'destination': 8, 'bandwidth': 80}
# {'source': 20, 'destination': 17, 'bandwidth': 100}
# {'source': 21, 'destination': 2, 'bandwidth': 80}
# {'source': 6, 'destination': 13, 'bandwidth': 40}
# {'source': 2, 'destination': 7, 'bandwidth': 60}
# {'source': 24, 'destination': 9, 'bandwidth': 40}
# {'source': 11, 'destination': 7, 'bandwidth': 80}
# {'source': 19, 'destination': 2, 'bandwidth': 60}
# {'source': 12, 'destination': 13, 'bandwidth': 60}
# {'source': 13, 'destination': 4, 'bandwidth': 40}
# {'source': 14, 'destination': 21, 'bandwidth': 120}
# {'source': 5, 'destination': 1, 'bandwidth': 60}
# {'source': 21, 'destination': 6, 'bandwidth': 60}
# {'source': 10, 'destination': 15, 'bandwidth': 60}
# {'source': 17, 'destination': 18, 'bandwidth': 40}
# {'source': 2, 'destination': 23, 'bandwidth': 80}
# {'source': 13, 'destination': 4, 'bandwidth': 40}
# {'source': 15, 'destination': 10, 'bandwidth': 120}
# {'source': 14, 'destination': 17, 'bandwidth': 100}
# {'source': 12, 'destination': 1, 'bandwidth': 40}
# {'source': 11, 'destination': 8, 'bandwidth': 40}
# {'source': 19, 'destination': 1, 'bandwidth': 100}
# {'source': 10, 'destination': 7, 'bandwidth': 40}
# {'source': 16, 'destination': 17, 'bandwidth': 120}
# {'source': 6, 'destination': 18, 'bandwidth': 100}
# {'source': 7, 'destination': 3, 'bandwidth': 100}
# {'source': 20, 'destination': 23, 'bandwidth': 40}
# {'source': 4, 'destination': 11, 'bandwidth': 40}
# {'source': 12, 'destination': 8, 'bandwidth': 120}
# {'source': 15, 'destination': 21, 'bandwidth': 40}
# {'source': 2, 'destination': 4, 'bandwidth': 100}
# {'source': 24, 'destination': 1, 'bandwidth': 80}
# {'source': 5, 'destination': 21, 'bandwidth': 100}
# {'source': 1, 'destination': 9, 'bandwidth': 100}
# {'source': 16, 'destination': 23, 'bandwidth': 40}
# {'source': 7, 'destination': 13, 'bandwidth': 120}
# {'source': 10, 'destination': 12, 'bandwidth': 40}
# {'source': 9, 'destination': 18, 'bandwidth': 60}
# {'source': 24, 'destination': 19, 'bandwidth': 100}
# {'source': 24, 'destination': 10, 'bandwidth': 40}
# {'source': 8, 'destination': 20, 'bandwidth': 80}
# {'source': 20, 'destination': 21, 'bandwidth': 120}
# {'source': 2, 'destination': 16, 'bandwidth': 40}
# {'source': 15, 'destination': 7, 'bandwidth': 120}
# {'source': 11, 'destination': 3, 'bandwidth': 40}
# {'source': 21, 'destination': 9, 'bandwidth': 100}
# {'source': 16, 'destination': 5, 'bandwidth': 40}
# {'source': 5, 'destination': 4, 'bandwidth': 100}
# {'source': 12, 'destination': 8, 'bandwidth': 60}
# {'source': 16, 'destination': 1, 'bandwidth': 100}
# {'source': 23, 'destination': 8, 'bandwidth': 120}
# {'source': 24, 'destination': 8, 'bandwidth': 80}
# {'source': 7, 'destination': 2, 'bandwidth': 80}
# {'source': 5, 'destination': 7, 'bandwidth': 120}
# {'source': 17, 'destination': 5, 'bandwidth': 120}
# {'source': 2, 'destination': 17, 'bandwidth': 40}
# {'source': 17, 'destination': 7, 'bandwidth': 60}
# {'source': 6, 'destination': 9, 'bandwidth': 80}
# {'source': 24, 'destination': 2, 'bandwidth': 100}
# {'source': 10, 'destination': 17, 'bandwidth': 60}
# {'source': 19, 'destination': 6, 'bandwidth': 60}
# {'source': 6, 'destination': 13, 'bandwidth': 100}
# {'source': 2, 'destination': 11, 'bandwidth': 120}
# {'source': 13, 'destination': 12, 'bandwidth': 40}
# {'source': 2, 'destination': 13, 'bandwidth': 80}
# {'source': 11, 'destination': 23, 'bandwidth': 100}
# {'source': 17, 'destination': 7, 'bandwidth': 120}
# {'source': 8, 'destination': 18, 'bandwidth': 120}
# {'source': 2, 'destination': 12, 'bandwidth': 80}
# {'source': 9, 'destination': 24, 'bandwidth': 100}
# {'source': 22, 'destination': 23, 'bandwidth': 60}
# {'source': 7, 'destination': 12, 'bandwidth': 80}
# {'source': 9, 'destination': 1, 'bandwidth': 80}
# {'source': 17, 'destination': 21, 'bandwidth': 120}
# {'source': 20, 'destination': 16, 'bandwidth': 120}
# {'source': 5, 'destination': 22, 'bandwidth': 120}
# {'source': 15, 'destination': 14, 'bandwidth': 40}
# {'source': 14, 'destination': 2, 'bandwidth': 60}
# {'source': 10, 'destination': 15, 'bandwidth': 60}
# {'source': 12, 'destination': 3, 'bandwidth': 100}
# {'source': 3, 'destination': 15, 'bandwidth': 80}
# {'source': 20, 'destination': 13, 'bandwidth': 40}
# {'source': 13, 'destination': 9, 'bandwidth': 100}
# {'source': 17, 'destination': 23, 'bandwidth': 60}
# {'source': 14, 'destination': 3, 'bandwidth': 100}
# {'source': 5, 'destination': 13, 'bandwidth': 80}
# {'source': 23, 'destination': 20, 'bandwidth': 80}
# {'source': 7, 'destination': 5, 'bandwidth': 60}
# {'source': 6, 'destination': 24, 'bandwidth': 120}
# {'source': 3, 'destination': 4, 'bandwidth': 120}
# {'source': 16, 'destination': 7, 'bandwidth': 100}
# {'source': 23, 'destination': 5, 'bandwidth': 60}
# {'source': 8, 'destination': 4, 'bandwidth': 120}
# {'source': 20, 'destination': 11, 'bandwidth': 40}
# {'source': 3, 'destination': 10, 'bandwidth': 40}
# {'source': 16, 'destination': 7, 'bandwidth': 40}
# {'source': 8, 'destination': 6, 'bandwidth': 120}
# {'source': 18, 'destination': 20, 'bandwidth': 120}
# {'source': 20, 'destination': 17, 'bandwidth': 60}
# {'source': 3, 'destination': 20, 'bandwidth': 40}
# {'source': 6, 'destination': 2, 'bandwidth': 120}
# {'source': 20, 'destination': 1, 'bandwidth': 120}
# {'source': 2, 'destination': 5, 'bandwidth': 120}
# {'source': 14, 'destination': 17, 'bandwidth': 120}
# {'source': 23, 'destination': 11, 'bandwidth': 60}
# {'source': 20, 'destination': 4, 'bandwidth': 100}
# {'source': 8, 'destination': 17, 'bandwidth': 60}
# {'source': 17, 'destination': 24, 'bandwidth': 100}
# {'source': 10, 'destination': 16, 'bandwidth': 80}
# {'source': 10, 'destination': 18, 'bandwidth': 100}
# {'source': 17, 'destination': 7, 'bandwidth': 120}
# {'source': 8, 'destination': 4, 'bandwidth': 100}
# {'source': 12, 'destination': 21, 'bandwidth': 60}
# {'source': 8, 'destination': 13, 'bandwidth': 120}
# {'source': 5, 'destination': 18, 'bandwidth': 40}
# {'source': 5, 'destination': 23, 'bandwidth': 60}
# {'source': 8, 'destination': 21, 'bandwidth': 40}
# {'source': 13, 'destination': 12, 'bandwidth': 60}
# {'source': 9, 'destination': 17, 'bandwidth': 40}
# {'source': 3, 'destination': 24, 'bandwidth': 40}
# {'source': 6, 'destination': 19, 'bandwidth': 60}
# {'source': 13, 'destination': 6, 'bandwidth': 80}
# {'source': 11, 'destination': 15, 'bandwidth': 60}
# {'source': 14, 'destination': 20, 'bandwidth': 100}
# {'source': 14, 'destination': 1, 'bandwidth': 120}
# {'source': 20, 'destination': 4, 'bandwidth': 80}
# {'source': 2, 'destination': 5, 'bandwidth': 100}
# {'source': 24, 'destination': 3, 'bandwidth': 80}
# {'source': 13, 'destination': 14, 'bandwidth': 40}
# {'source': 6, 'destination': 13, 'bandwidth': 40}
# {'source': 18, 'destination': 8, 'bandwidth': 60}
# {'source': 9, 'destination': 13, 'bandwidth': 40}
# {'source': 24, 'destination': 11, 'bandwidth': 40}
# {'source': 4, 'destination': 13, 'bandwidth': 60}
# {'source': 4, 'destination': 15, 'bandwidth': 100}
# {'source': 9, 'destination': 1, 'bandwidth': 80}
# {'source': 13, 'destination': 5, 'bandwidth': 80}
# {'source': 24, 'destination': 1, 'bandwidth': 120}
# {'source': 14, 'destination': 3, 'bandwidth': 40}
