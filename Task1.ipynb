# %%
import random
def generate_requests(node_request ,num_requests, demand):
    requests = []
    for _ in range(num_requests):
        source = random.randint(1, node_request)
        destination = random.randint(1, node_request)
        #for making sure source and destination is not same
        while destination == source:
            destination = random.randint(1, node_request)
            
            
        if demand_type == 'variable':
            demand = 20 * random.choice([2, 3, 4, 5, 6])
        else:
            demand = demand  # fixed demand
        
        new_req={
            "source":source,
            "destination":destination,
            "bandwidth":demand
        }
        
        requests.append(new_req)
        
    return requests
node_request = int(input("Enter the maximum number of nodes : "))
num_requests = int(input("Enter the number of requests: "))
demand_type = input("Enter demand type (40 or 80 for fixed, or variable): ").lower()

if demand_type == '40':
    demand = 40
elif demand_type == '80':
    demand = 80
elif demand_type == 'variable':
    demand = "variable"
else:
    print("Invalid demand type.")
    exit()

result = generate_requests(node_request ,num_requests, demand)
for req in result:
    print(req)

# print(result)
# Out:
# {'source': 10, 'destination': 3, 'bandwidth': 60}
# {'source': 3, 'destination': 7, 'bandwidth': 120}
# {'source': 3, 'destination': 2, 'bandwidth': 120}
# {'source': 9, 'destination': 1, 'bandwidth': 80}
# {'source': 10, 'destination': 4, 'bandwidth': 120}
# {'source': 6, 'destination': 1, 'bandwidth': 80}
# {'source': 4, 'destination': 7, 'bandwidth': 100}
# {'source': 9, 'destination': 7, 'bandwidth': 60}
# {'source': 10, 'destination': 8, 'bandwidth': 100}
# {'source': 4, 'destination': 5, 'bandwidth': 40}
# {'source': 2, 'destination': 7, 'bandwidth': 100}
# {'source': 4, 'destination': 3, 'bandwidth': 100}
# {'source': 7, 'destination': 10, 'bandwidth': 40}
# {'source': 6, 'destination': 4, 'bandwidth': 100}
# {'source': 6, 'destination': 1, 'bandwidth': 80}
# {'source': 7, 'destination': 8, 'bandwidth': 100}
# {'source': 9, 'destination': 5, 'bandwidth': 80}
# {'source': 8, 'destination': 1, 'bandwidth': 100}
# {'source': 7, 'destination': 3, 'bandwidth': 80}
# ...
